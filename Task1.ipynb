# %%
# !git --version
# Out:
# git version 2.54.0.windows.1

# %%
# !git config --global user.name "Eyob Girma"
# !git config --global user.email "eyobg291@gmail.com
# !git config --global init.defaultBranch main

# Confirm
# !git config --global --list
# Out:
# user.name=Eyob Girma
# user.email=eyobg291@gmail.com
# init.defaultbranch=main

# %%
import os

REP0_URL = "https://github.com/eyobg05/week1-slack-analysis.git"
REP0_NAME = "week1-slack-analysis"

# !git clone {REP0_URL}

os.chdir(REP0_NAME)
print("Now inside:", os.getcwd())
# Out:
# Now inside: C:\Users\eyobg\Desktop\anonymized_new\notebook\week1-slack-analysis\week1-slack-analysis
# Cloning into 'week1-slack-analysis'...

# %%
print(os.getcwd())
# !git status
# Out:
# C:\Users\eyobg\Desktop\anonymized_new\notebook\week1-slack-analysis\week1-slack-analysis
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is F0BB-AFA2
#
#  Directory of C:\Users\eyobg\Desktop\anonymized_new\notebook\week1-slack-analysis\week1-slack-analysis
#
# 2026-06-06  06:54 AM    <DIR>          .
# 2026-06-06  06:54 AM    <DIR>          ..
# 2026-06-06  06:54 AM             4,846 .gitignore
#                1 File(s)          4,846 bytes
#                2 Dir(s)  357,712,297,984 bytes free

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is F0BB-AFA2
#
#  Directory of C:\Users\eyobg\Desktop\anonymized_new\notebook\week1-slack-analysis
#
# 2026-06-09  11:04 AM    <DIR>          .
# 2026-06-09  11:03 AM    <DIR>          ..
# 2026-06-04  11:57 PM             4,846 .gitignore
# 2026-06-09  11:04 AM    <DIR>          .ipynb_checkpoints
# 2026-06-06  09:47 AM             3,648 Task1.ipynb
#                2 File(s)          8,494 bytes
#                3 Dir(s)  355,887,259,648 bytes free

# %%
cd week1-slack-analysis
# Out:
# [WinError 2] The system cannot find the file specified: 'week1-slack-analysis'
# C:\Users\eyobg\Desktop\anonymized_new\notebook\week1-slack-analysis

# %%
cd notebook
# Out:
# [WinError 2] The system cannot find the file specified: 'notebook'
# C:\Users\eyobg\Desktop\anonymized_new\notebook\week1-slack-analysis

# %%
import os

folders = {
    '.github/workflows',
    '.vscode',
    'notebooks',
    'src',
    'tests',
    'docs',
    'data/anonymized',
}

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}/')

print('\nAll folders created.')
# Out:
# Created: src/
# Created: data/anonymized/
# Created: notebooks/
# Created: .vscode/
# Created: docs/
# Created: .github/workflows/
# Created: tests/
#
# All folders created.

# %%
pwd
# Out:
# 'C:\\Users\\eyobg\\Desktop\\Internship Training\\notebook\\week1-slack-analysis'

# %%
cd notebooks/
# Out:
# C:\Users\eyobg\Desktop\Internship Training\notebook\week1-slack-analysis\notebooks
